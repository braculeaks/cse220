# %%
import numpy as np

# %% [markdown]
# # **Max Heap Class**

# %%
class MaxHeap:

  def __init__(self, capacity):
    self.heap = np.zeros(capacity, dtype = int)
    self.size = 0

  def swap(self, i, j):
    temp = self.heap[i]
    self.heap[i] = self.heap[j]
    self.heap[j] = temp

  def insert(self, val):
    if self.size == len(self.heap) - 1:
      return "Insertion is not possible"
    self.size += 1
    self.heap[self.size] = val
    self.swim()

  def swim(self):
    child = self.size
    parent = child // 2
    while parent > 0 and self.heap[parent] < self.heap[child]:
      self.swap(parent, child)
      child = parent
      parent = child // 2

  def delete(self):
    #Implement it yourself. You can follow the class recording.

  def sink(self):
    #Implement it yourself. You can follow the class recording.

  def printHeap(self):
    for i in range(len(self.heap)):
      print(self.heap[i], end = " ")
    print()

# %%
arr = [91, 52, 35, 6]
maxHeap = MaxHeap(6)

for i in range(len(arr)):
  maxHeap.insert(arr[i])

maxHeap.printHeap()
maxHeap.insert(70)
maxHeap.printHeap()
# Out:
# 0 91 52 35 6 0
# 0 91 70 35 6 52

# %%
val = maxHeap.delete()
print(val)
# Out:
# 91

# %%
while True:
  val = maxHeap.delete()
  if val != "Deletion not possible":
    print(val)
  else:
    break
# Out:
# 70
# 52
# 35
# 6

# %%
#Also implement the Min Heap class. Practice the problems from lab and previous final questions.
